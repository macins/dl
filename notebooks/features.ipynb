# %%
import polars as pl

# %%
df = pl.read_parquet("../data/data.parquet")

# %%
df = df.with_columns([
    pl.col("Time").dt.month().alias("DATA_month")
]).drop("month")

# %%
df.write_parquet("../data/data.parquet")

# %%
df
# Out:
# shape: (20_620_785, 114)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Time       ┆ Symbol ┆ DATA_secto ┆ feature_m ┆ … ┆ DATA_is_d ┆ DATA_is_t ┆ DATA_is_l ┆ DATA_mont │
# │ ---        ┆ ---    ┆ r          ┆ tm_5_zsco ┆   ┆ ay_sessio ┆ rading_ho ┆ ast_30min ┆ h         │
# │ datetime[μ ┆ str    ┆ ---        ┆ re10_neut ┆   ┆ n         ┆ ur        ┆ ---       ┆ ---       │
# │ s]         ┆        ┆ str        ┆ ral…      ┆   ┆ ---       ┆ ---       ┆ bool      ┆ i8        │
# │            ┆        ┆            ┆ ---       ┆   ┆ bool      ┆ bool      ┆           ┆           │
# │            ┆        ┆            ┆ f32       ┆   ┆           ┆           ┆           ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.0       ┆ … ┆ true      ┆ true      ┆ false     ┆ 9         │
# │ 09:00:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.128892  ┆ … ┆ true      ┆ true      ┆ false     ┆ 9         │
# │ 09:01:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.176722  ┆ … ┆ true      ┆ true      ┆ false     ┆ 9         │
# │ 09:02:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.210379  ┆ … ┆ true      ┆ true      ┆ false     ┆ 9         │
# │ 09:03:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.33723   ┆ … ┆ true      ┆ true      ┆ false     ┆ 9         │
# │ 09:04:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …      ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ -0.062283 ┆ … ┆ true      ┆ true      ┆ false     ┆ 5         │
# │ 10:36:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ -0.192088 ┆ … ┆ true      ┆ true      ┆ false     ┆ 5         │
# │ 10:37:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.139028  ┆ … ┆ true      ┆ true      ┆ false     ┆ 5         │
# │ 10:38:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.63143   ┆ … ┆ true      ┆ true      ┆ false     ┆ 5         │
# │ 10:39:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.540286  ┆ … ┆ true      ┆ true      ┆ false     ┆ 5         │
# │ 10:40:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
