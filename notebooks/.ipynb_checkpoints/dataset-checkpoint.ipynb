# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import polars as pl
from datetime import datetime
from tqdm.auto import tqdm
import sys
sys.path.append("/root/autodl-tmp/jump")
from scripts.build_final_features import FINAL_FEATURES
from jump_dl.src.dataio import build_slice_dataloader

# %%
df = pl.read_parquet("../data/data.parquet")

# %%
# Out:
# shape: (20_620_785, 123)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Time       ┆ Symbol ┆ DATA_secto ┆ feature_m ┆ … ┆ DATA_mont ┆ DATA_week ┆ DATA_sect ┆ DATA_exch │
# │ ---        ┆ ---    ┆ r          ┆ tm_5_zsco ┆   ┆ h         ┆ day       ┆ or_right  ┆ ange      │
# │ datetime[μ ┆ str    ┆ ---        ┆ re10_neut ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ s]         ┆        ┆ str        ┆ ral…      ┆   ┆ i8        ┆ i8        ┆ str       ┆ str       │
# │            ┆        ┆            ┆ ---       ┆   ┆           ┆           ┆           ┆           │
# │            ┆        ┆            ┆ f32       ┆   ┆           ┆           ┆           ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.0       ┆ … ┆ 9         ┆ 2         ┆ nongfucha ┆ DCE       │
# │ 09:00:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆ npin      ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.128892  ┆ … ┆ 9         ┆ 2         ┆ nongfucha ┆ DCE       │
# │ 09:01:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆ npin      ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.176722  ┆ … ┆ 9         ┆ 2         ┆ nongfucha ┆ DCE       │
# │ 09:02:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆ npin      ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.210379  ┆ … ┆ 9         ┆ 2         ┆ nongfucha ┆ DCE       │
# │ 09:03:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆ npin      ┆           │
# │ 2013-09-17 ┆ A      ┆ nongfuchan ┆ 0.33723   ┆ … ┆ 9         ┆ 2         ┆ nongfucha ┆ DCE       │
# │ 09:04:00   ┆        ┆ pin        ┆           ┆   ┆           ┆           ┆ npin      ┆           │
# │ …          ┆ …      ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ -0.062283 ┆ … ┆ 5         ┆ 2         ┆ yousejins ┆ SHFE      │
# │ 10:36:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆ hu        ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ -0.192088 ┆ … ┆ 5         ┆ 2         ┆ yousejins ┆ SHFE      │
# │ 10:37:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆ hu        ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.139028  ┆ … ┆ 5         ┆ 2         ┆ yousejins ┆ SHFE      │
# │ 10:38:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆ hu        ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.63143   ┆ … ┆ 5         ┆ 2         ┆ yousejins ┆ SHFE      │
# │ 10:39:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆ hu        ┆           │
# │ 2020-05-26 ┆ ZN     ┆ yousejinsh ┆ 0.540286  ┆ … ┆ 5         ┆ 2         ┆ yousejins ┆ SHFE      │
# │ 10:40:00   ┆        ┆ u          ┆           ┆   ┆           ┆           ┆ hu        ┆           │
# └────────────┴────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
loader = build_slice_dataloader(
    df=df,
    feature_cols={"cont": FINAL_FEATURES},
    target_cols=["ret_30min"],
    symbol_col="Symbol",
    time_col="Time",
    batch_size=64,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    prefetch_factor=4,
    persistent_workers=True,
)
